# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17583232140122971119,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 2247832372
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9398990329237622850
#  physical_device_desc: "device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import PIL

from sklearn.metrics import confusion_matrix

from keras.preprocessing.image import ImageDataGenerator, array_to_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
import warnings
from datetime import datetime

warnings.filterwarnings('ignore')

# %%
hyper_dimension = 500
hyper_epochs = 100
hyper_batch_size = 16
hyper_feature_maps = 32
hyper_channels = 1
hyper_mode = 'grayscale'

# %%
# Initializing the CNN
classifier = Sequential()

# Convolution & pooling - First convolution layer
classifier.add(Conv2D(hyper_feature_maps, (3, 3),
                      input_shape = (hyper_dimension,
                                     hyper_dimension,
                                     hyper_channels),
                      activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Convolution & pooling - Second convolution layer (same as first layer)
classifier.add(Conv2D(hyper_feature_maps, (3, 3),
                      input_shape = (hyper_dimension,
                                     hyper_dimension,
                                     hyper_channels),
                      activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Convolution & pooling - Third convolution layer
classifier.add(Conv2D(hyper_feature_maps * 2, (3, 3),
                      input_shape = (hyper_dimension,
                                     hyper_dimension,
                                     hyper_channels),
                      activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Flattening
classifier.add(Flatten())

# Full connection
classifier.add(Dense(units = hyper_feature_maps * 2, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam',
                   loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 498, 498, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 249, 249, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 247, 247, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 123, 123, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 121, 121, 64)      18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 230400)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                14745664
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 14,773,793
# Trainable params: 14,773,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Creating training and validation image flows

train_gen = ImageDataGenerator(rescale = 1./255,
                               shear_range = 0.2,
                               zoom_range = 0.2,
                               vertical_flip = True)

val_gen = ImageDataGenerator(rescale = 1./255)

train_set = train_gen.flow_from_directory('train',
                                          target_size = (hyper_dimension,
                                                         hyper_dimension),
                                          batch_size = hyper_batch_size,
                                          class_mode = 'binary',
                                          color_mode = hyper_mode)

val_set = val_gen.flow_from_directory('val',
                                      target_size = (hyper_dimension,
                                                     hyper_dimension),
                                      batch_size = hyper_batch_size,
                                      class_mode = 'binary',
                                      color_mode = hyper_mode)
# Out:
# Found 4193 images belonging to 2 classes.
# Found 1040 images belonging to 2 classes.

# %%
# Visualizing images in the first training set batch 

image_batch = train_set[0][0]

plt.figure(figsize=(20,5))
for i in range(len(image_batch)):
    plt.subplot(2,8,i+1)
    pil_img = array_to_img(image_batch[i])
    plt.imshow(pil_img,cmap='gray')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Fitting the model
start_time = datetime.now()
results = classifier.fit_generator(train_set,
                                   steps_per_epoch = len(train_set),
                                   epochs = hyper_epochs,
                                   validation_data = val_set,
                                   validation_steps = len(val_set))
datetime.now() - start_time
# Out:
# Epoch 1/100
# 263/263 [==============================] - 113s 362ms/step - loss: 0.5680 - accuracy: 0.7380 - val_loss: 0.2043 - val_accuracy: 0.9240
# Epoch 2/100
# 263/263 [==============================] - 89s 339ms/step - loss: 0.2545 - accuracy: 0.8867 - val_loss: 0.1683 - val_accuracy: 0.9346
# Epoch 86/100
# 263/263 [==============================] - 93s 352ms/step - loss: 0.0454 - accuracy: 0.9855 - val_loss: 0.0943 - val_accuracy: 0.9692
# Epoch 87/100
# 263/263 [==============================] - 93s 352ms/step - loss: 0.0386 - accuracy: 0.9857 - val_loss: 0.1250 - val_accuracy: 0.9606
# Epoch 88/100
# 263/263 [==============================] - 92s 351ms/step - loss: 0.0472 - accuracy: 0.9864 - val_loss: 0.1064 - val_accuracy: 0.9654
# Epoch 89/100
# 263/263 [==============================] - 92s 348ms/step - loss: 0.0409 - accuracy: 0.9844 - val_loss: 0.1290 - val_accuracy: 0.9587
# Epoch 90/100
# 263/263 [==============================] - 92s 348ms/step - loss: 0.0429 - accuracy: 0.9835 - val_loss: 0.0986 - val_accuracy: 0.9663
# Epoch 91/100
# 263/263 [==============================] - 92s 349ms/step - loss: 0.0299 - accuracy: 0.9877 - val_loss: 0.1212 - val_accuracy: 0.9654
# Epoch 92/100
# 263/263 [==============================] - 92s 349ms/step - loss: 0.0523 - accuracy: 0.9822 - val_loss: 0.1711 - val_accuracy: 0.9413
# Epoch 93/100
# 263/263 [==============================] - 91s 345ms/step - loss: 0.0377 - accuracy: 0.9859 - val_loss: 0.1320 - val_accuracy: 0.9625
# Epoch 94/100
# 263/263 [==============================] - 90s 340ms/step - loss: 0.0313 - accuracy: 0.9891 - val_loss: 0.1549 - val_accuracy: 0.9577
# Epoch 95/100
# 263/263 [==============================] - 90s 341ms/step - loss: 0.0399 - accuracy: 0.9866 - val_loss: 0.1087 - val_accuracy: 0.9673
# Epoch 96/100
# 263/263 [==============================] - 91s 344ms/step - loss: 0.0328 - accuracy: 0.9865 - val_loss: 0.1316 - val_accuracy: 0.9615
# Epoch 97/100
# 263/263 [==============================] - 91s 346ms/step - loss: 0.0431 - accuracy: 0.9854 - val_loss: 0.1426 - val_accuracy: 0.9587
# Epoch 98/100
# 263/263 [==============================] - 90s 342ms/step - loss: 0.0301 - accuracy: 0.9868 - val_loss: 0.1100 - val_accuracy: 0.9692
# Epoch 99/100
# 263/263 [==============================] - 91s 347ms/step - loss: 0.0307 - accuracy: 0.9886 - val_loss: 0.1186 - val_accuracy: 0.9663
# Epoch 100/100
# 263/263 [==============================] - 91s 347ms/step - loss: 0.0359 - accuracy: 0.9862 - val_loss: 0.1161 - val_accuracy: 0.9635
# datetime.timedelta(seconds=9727, microseconds=175046)

# %%
# Creating test image flow

test_gen = ImageDataGenerator(rescale = 1./255)

test_set = test_gen.flow_from_directory('test',
                                        target_size = (hyper_dimension,
                                                       hyper_dimension),
                                        batch_size = 1,
                                        class_mode = None,
                                        color_mode = hyper_mode,
                                        shuffle=False)

# Making predictions

predictions = classifier.predict_generator(test_set)
predictions[predictions <= 0.5] = 0
predictions[predictions > 0.5] = 1
# Out:
# Found 624 images belonging to 2 classes.

# %%
# Confusion matrix

cm = pd.DataFrame(data=confusion_matrix(test_set.classes, predictions, labels=[0, 1]),
                  index=["Actual Normal", "Actual Pneumonia"],
                  columns=["Predicted Normal", "Predicted Pneumonia"])
cm
# Out:
#                   Predicted Normal  Predicted Pneumonia
# Actual Normal                  191                   43
# Actual Pneumonia                 7                  383
